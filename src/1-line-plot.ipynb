# %% [markdown]
# ### Exercise 1: Line Plot Customization

# %%
# TASK: Create a line plot with x values ranging from 0 to 10 and y values as the square of x.
# Customize the plot by adding a title, labels for both axes, and a grid.

# %%
import matplotlib.pyplot as plt
import numpy as np

try:
    # Generate x values from 0 to 10
    x = np.arange(0, 11, 1)
    y = x**2  # Compute square of x values

    # Ensure x and y lists are not empty and have the same length
    if not len(x) or not len(y):
        raise ValueError("X or Y data list is empty.")
    if len(x) != len(y):
        raise ValueError("X and Y lists must have the same length.")

    # Create the plot
    plt.figure(figsize=(6, 4))
    plt.plot(x, y, marker='o', linestyle='-', color='blue', label='y = x^2')

    # Add title and labels
    plt.title('Line Plot of y = x^2')
    plt.xlabel('X values')
    plt.ylabel('Y values')

    # Add grid and legend
    plt.grid(True)
    plt.legend()

    # Show plot
    plt.show()

except ValueError as ve:
    print(f"ValueError: {ve}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
